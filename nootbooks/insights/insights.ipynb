# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Load the updated dataset
df = pd.read_csv("../../data/bank_reviews_analysis.csv")

# Normalize column names
df.columns = df.columns.str.strip().str.lower()

# 1. Sentiment distribution
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='sentiment_label', palette='Set2')
plt.title('Sentiment Distribution of App Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.tight_layout()
plt.show()

# 2. Sentiment distribution by bank
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='bank', hue='sentiment_label', palette='Set2')
plt.title('Sentiment Distribution by Bank')
plt.xlabel('Bank')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. Theme distribution
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='theme', order=df['theme'].value_counts().index, palette='pastel')
plt.title('Most Frequent Themes in User Reviews')
plt.xlabel('Theme')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 4. Word cloud for negative reviews
neg_text = " ".join(df[df['sentiment_label'] == 'negative']['review'].dropna().astype(str))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(neg_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common Keywords in Negative Reviews")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16100\2176758738.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sentiment_label', palette='Set2')
# C:\Users\pc\AppData\Local\Temp\ipykernel_16100\2176758738.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='theme', order=df['theme'].value_counts().index, palette='pastel')
